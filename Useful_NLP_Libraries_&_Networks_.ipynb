# %% [markdown]
#  1: Compare and contrast NLTK and spaCy in terms of features, ease of use,
# and performance. ?
#
# Answer:
#
# NLTK vs spaCy — Comparison
# 1. Features
#  NLTK (Natural Language Toolkit)
#
# One of the oldest NLP libraries (very comprehensive).
#
# Includes:
#
# Tokenizers
#
# Stemmers & lemmatizers
#
# POS tagging
#
# Parsing (CFG, PCFG, Dependency, Constituency)
#
# Named Entity Recognition
#
# Sentiment analysis tools
#
# Text classification tools
#
# Corpora (WordNet, Brown, Gutenberg, Movie Reviews, etc.)
#
# Great for research, teaching, and experimentation.
#
# Has many rule-based and algorithm-based NLP models.
#
#  spaCy
#
# Modern industrial-grade library built for production NLP.
#
# Includes:
#
# Faster tokenization
#
# Dependency parsing
#
# Lemmatization
#
# POS tagging
#
# Named Entity Recognition (NER)
#
# Text classification
#
# Word vectors
#
# Pretrained transformer pipeline support
#
# Efficient custom pipeline building
#
# Focuses on practical NLP tasks with state-of-the-art models.
#
# 2. Ease of Use
#  NLTK
#
# Syntax is longer and requires more steps.
#
# Many functions require manually downloading data via nltk.download().
#
# Good for beginners learning NLP theory.
#
# Code is more “academic style.”

# %% [markdown]
# ---

# %% [markdown]
# 2: What is TextBlob and how does it simplify common NLP tasks like
# sentiment analysis and translation?
#
# Answer:
#
# TextBlob is a simple, high-level Python library built on top of NLTK and Pattern that provides an easy API for performing common NLP tasks.
#
# It is designed to make NLP beginner-friendly, with very clean syntax and built-in functions for frequently used tasks.
#
# 1. Sentiment Analysis (Very Easy)
#
# TextBlob has a built-in sentiment analyzer that returns:
#
# polarity (range: −1 to +1 → negative to positive)
#
# subjectivity (range: 0 to 1 → objective to subjective)
#
# TextBlob is a high-level NLP library built on top of NLTK and Pattern that makes NLP tasks extremely simple using a clean, Pythonic API. It simplifies tasks like sentiment analysis and translation through built-in functions. For example, TextBlob can analyze sentiment using blob.sentiment and translate text with blob.translate() without requiring model training or complex setup. It’s ideal for beginners, prototypes, or quick NLP tasks.

# %% [markdown]
# ---

# %% [markdown]
# **3: Explain the role of Standford NLP in academic and industry NLP Projects.?**
#
# Answer:
#
# Stanford NLP, developed by Stanford University, is a powerful suite of NLP tools known for its accuracy, robustness, and rich linguistic analysis. It includes tools like:
#
# Stanford CoreNLP
#
# Stanford POS Tagger
#
# Stanford Named Entity Recognizer (NER)
#
# Stanford Parser
#
# Stanford Sentiment Analyzer
#
# Stanford Stanza (Python-based modern version)
#
# Stanford NLP plays a major role in both academic and industry NLP projects because of its high-quality, linguistically rich models. In academics, it is widely used for research involving parsing, coreference resolution, and deep language analysis due to its accuracy and reproducibility. In industry, Stanford NLP (CoreNLP and Stanza) is used in large-scale enterprise applications for tasks like NER, sentiment analysis, and information extraction, especially in domains such as legal, healthcare, and finance. Its stability, Java-based architecture, and support for multiple languages make it valuable for production-grade NLP pipelines.

# %% [markdown]
# ---

# %% [markdown]
# 4: Describe the architecture and functioning of a Recurrent Natural Network
# (RNN).
#
# Answer:
#
# A Recurrent Neural Network (RNN) is a type of neural network designed to process sequential data such as text, speech, time-series, and videos.
# It learns patterns across time steps by maintaining a memory of past inputs.
#
# A Recurrent Neural Network (RNN) is a neural architecture designed for sequential data. It contains a recurrent hidden layer that processes one input at a time while carrying information from previous time steps using a hidden state. At each time step, the hidden state is updated based on the current input and previous state: hₜ = f(Wₓxₜ + Wₕhₜ₋₁ + b). This allows RNNs to learn temporal patterns and dependencies. They are used in NLP, speech, and time-series tasks. However, standard RNNs struggle with long-term dependencies due to vanishing and exploding gradients, which led to improved models like LSTMs and GRUs.

# %% [markdown]
# ---

# %% [markdown]
# 5: What is the key difference between LSTM and GRU networks in NLP applications?
#
# Answer:
#
# 1. Architecture Differences
# ⭐ LSTM (Long Short-Term Memory)
#
# Has 3 gates:
#
# Input gate
#
# Forget gate
#
# Output gate
#
# Has a separate cell state (Cₜ) and hidden state (hₜ).
#
# The key difference between LSTM and GRU is their internal gate structure. LSTMs use three gates (input, forget, output) and maintain a separate cell state, making them more complex and better at capturing long-term dependencies. GRUs use only two gates (update and reset) and combine the cell state with the hidden state, making them simpler, faster, and more memory-efficient. In practice, LSTMs may perform slightly better on long-sequence NLP tasks, while GRUs train faster and work well for most applications with similar accuracy.

# %% [markdown]
# ---

# %% [markdown]
# 6: Write a Python program using TextBlob to perform sentiment analysis on the following paragraph of text: “I had a great experience using the new mobile banking app. The interface is intuitive, and customer support was quick to resolve my issue. However, the app did crash once during a transaction, which was frustrating" Your program should print out the polarity and subjectivity scores. (Include your Python code and output in the code box below.)
#
# Answer:

# %%
from textblob import TextBlob

# Given paragraph
text = """I had a great experience using the new mobile banking app.
The interface is intuitive, and customer support was quick to resolve my issue.
However, the app did crash once during a transaction, which was frustrating."""

# Create TextBlob object
blob = TextBlob(text)

# Get sentiment
sentiment = blob.sentiment

# Print results
print("Polarity:", sentiment.polarity)
print("Subjectivity:", sentiment.subjectivity)

# %% [markdown]
# ---

# %% [markdown]
# 7: Given the sample paragraph below, perform string tokenization and frequency distribution using Python and NLTK: “Natural Language Processing (NLP) is a fascinating field that combines linguistics, computer science, and artificial intelligence. It enables machines to understand, interpret, and generate human language. Applications of NLP include chatbots, sentiment analysis, and machine translation. As technology advances, the role of NLP in modern solutions is becoming increasingly critical.” (Include your Python code and output in the code box below.)

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

# Download NLTK resources (only needed once)
nltk.download('punkt')

# Sample paragraph
text = """Natural Language Processing (NLP) is a fascinating field that combines linguistics,
computer science, and artificial intelligence. It enables machines to understand,
interpret, and generate human language. Applications of NLP include chatbots,
sentiment analysis, and machine translation. As technology advances, the role of NLP
in modern solutions is becoming increasingly critical."""

# Tokenize the text
tokens = word_tokenize(text)

# Print tokens
print("Tokenized Words:\n", tokens)

# Frequency Distribution
freq_dist = FreqDist(tokens)

print("\nFrequency Distribution:")
for word, freq in freq_dist.items():
    print(f"{word}: {freq}")

# %% [markdown]
# ---

# %% [markdown]
# 8: Implement a basic LSTM model in Keras for a text classification task using the following dummy dataset. Your model should classify sentences as either positive (1) or negative (0). # Dataset texts = [ “I love this project”, #Positive “This is an amazing experience”, #Positive “I hate waiting in line”, #Negative “This is the worst service”, #Negative “Absolutely fantastic!” #Positive ] labels = [1, 1, 0, 0, 1] Preprocess the text, tokenize it, pad sequences, and build an LSTM model to train on this data. You may use Keras with TensorFlow backend. (Include your Python code and output in the code box below.)

# %%
# Import required libraries
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# Dataset
texts = [
    "I love this project",       # Positive
    "This is an amazing experience",  # Positive
    "I hate waiting in line",    # Negative
    "This is the worst service", # Negative
    "Absolutely fantastic!"      # Positive
]
labels = [1, 1, 0, 0, 1]

# Step 1: Tokenization
tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts)

# Convert texts to sequences of integers
sequences = tokenizer.texts_to_sequences(texts)
print("Sequences:", sequences)

# Step 2: Padding sequences
max_length = max(len(x) for x in sequences)
padded_sequences = pad_sequences(sequences, maxlen=max_length, padding='post')

print("\nPadded Sequences:\n", padded_sequences)

# Step 3: Convert labels to numpy array
labels = np.array(labels)

# Step 4: Build the LSTM Model
model = Sequential()
model.add(Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=16, input_length=max_length))
model.add(LSTM(32))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Step 5: Train the model
history = model.fit(padded_sequences, labels, epochs=10, verbose=1)

# Step 6: Evaluate the model
loss, accuracy = model.evaluate(padded_sequences, labels, verbose=0)
print("\nTraining Accuracy:", accuracy)

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# 9: Using spaCy, build a simple NLP pipeline that includes tokenization, lemmatization, and entity recognition. Use the following paragraph as your dataset: “Homi Jehangir Bhaba was an Indian nuclear physicist who played a key role in the development of India’s atomic energy program. He was the founding director of the Tata Institute of Fundamental Research (TIFR) and was instrumental in establishing the Atomic Energy Commission of India.” Write a Python program that processes this text using spaCy, then prints tokens, their lemmas, and any named entities found. (Include your Python code and output in the code box below.)

# %%
import spacy

# Load spaCy English model
nlp = spacy.load("en_core_web_sm")

# Given paragraph
text = """
Homi Jehangir Bhaba was an Indian nuclear physicist who played a key role in the
development of India’s atomic energy program. He was the founding director of the Tata
Institute of Fundamental Research (TIFR) and was instrumental in establishing the
Atomic Energy Commission of India.
"""

# Process text
doc = nlp(text)

# 1. Tokenization + Lemmatization
print("Tokens and Lemmas:")
for token in doc:
    if not token.is_space:  # ignore spaces
        print(f"{token.text:<15}  -->  {token.lemma_}")

# 2. Named Entity Recognition
print("\nNamed Entities:")
for ent in doc.ents:
    print(f"{ent.text:<40}  |  {ent.label_}")

# %% [markdown]
# ---

# %% [markdown]
# 10: You are working on a chatbot for a mental health platform. Explain how
# you would leverage LSTM or GRU networks along with libraries like spaCy or Stanford
# NLP to understand and respond to user input effectively. Detail your architecture, data
# preprocessing pipeline, and any ethical considerations.
# (Include your Python code and output in the code box below.)
#
#
# Answer;
#
# High-level architecture (textual diagram)
#
# User → Frontend (web/mobile)
#
# Input Sanitizer & Rate-Limiter (basic filtering, remove PII where possible)
#
# Preprocessing (spaCy / Stanza): tokenization, lemmatization, POS, NER, sentiment, extract triggers (e.g., self-harm words)
#
# Classifier (LSTM or GRU): intent classification & crisis-risk scoring (multi-head optional)
#
# Dialogue Manager:
#
# If crisis-risk == high → immediate escalation handler (human + emergency resources)
#
# Else choose policy: retrieval template, empathetic response generator, or follow-up question
#
# Response Safety Filter (block medical advice, verify disclaimers)
#
# Logger (secure) → audit trail, but store minimal PII; encryption at rest/in-transit
#
# Human-in-the-loop fallback / review queue
#
# 1. System Architecture
# A. Input → Preprocessing Layer (spaCy / Stanford NLP)
#
# Use spaCy or Stanford NLP for:
#
# Tokenization
#
# Lemmatization
#
# Named Entity Recognition (NER) to detect sensitive entities (names, locations)
#
# Dependency parsing to understand sentence intent
#
# Sentiment scoring
# This creates clean, normalized representations for the model.
#
# B. LSTM/GRU Intent & Emotion Classification Model
#
# A neural model (LSTM or GRU) classifies:
#
# User intent (e.g., distress, information seeking, gratitude, small talk)
#
# Emotional state (sadness, fear, anger)
#
# Crisis severity (normal → moderate → high-risk)
#
# Why LSTM/GRU?
#
# Handle sequential patterns in language
#
# Capture long-term emotional dependencies
#
# Lightweight and fast for real-time chat systems
#
# C. Dialogue Manager
#
# Based on model predictions:
#
# If high-risk → trigger Crisis Response Module
#
# If low-risk → generate empathetic text
#
# If informational → provide resources
#
# D. Crisis Response Module
#
# If the system detects suicidality/self-harm:
#
# Provide immediate crisis hotline resources
#
# Encourage user to reach out to a trusted person
#
# Avoid giving medical or diagnostic advice
#
# Trigger human-in-the-loop escalation
#
# 2. Data Preprocessing Pipeline
#
# Text cleaning
#
# Lowercase, remove noise, mask PII
#
# spaCy processing
#
# Tokenize, lemmatize
#
# Extract entities (NER)
#
# Generate spaCy vector embeddings or use tokenizer → sequence ids
#
# Sequence preparation
#
# Convert to integer sequences
#
# Pad sequences
#
# Labels
#
# Intent (multi-class)
#
# Crisis flag (binary)
#
# Train LSTM/GRU
#
# Loss = cross entropy + binary loss
#
# Optimizer = Adam
#
# Use class balancing due to severe class imbalance in crisis cases
#
# 3. Ethical Considerations
# ✔ Safety
#
# Must never give medical, clinical, or harmful advice
#
# Must escalate if a self-harm intent appears
#
# Rule-based safety net + model-based detection
#
# ✔ Privacy
#
# Remove personal data before storage
#
# Encrypt logs & use minimal retention
#
# Ensure GDPR/HIPAA compliance
#
# ✔ Transparency
#
# Tell users you are not a human
#
# Provide disclaimers
#
# Provide crisis hotlines
#
# ✔ Bias & Fairness
#
# Evaluate model across languages & dialects
#
# Avoid harmful bias in crisis detection
#
# ✅ 4. Python Code + Output (as required)
#
# Below is a clean exam-friendly Python script demonstrating:
# ✔ spaCy preprocessing
# ✔ GRU model training
# ✔ Sample output

# %%
# -----------------------------
# Mental Health Chatbot Example
# Using spaCy + GRU network
# -----------------------------

import spacy
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, GRU, Dense
from tensorflow.keras.optimizers import Adam

# -----------------------------
# 1. Load spaCy
# -----------------------------
nlp = spacy.load("en_core_web_sm")

def preprocess(text):
    """
    Tokenize + Lemmatize using spaCy
    Remove punctuation and convert to lowercase
    """
    doc = nlp(text)
    tokens = []
    for t in doc:
        if not t.is_punct:
            tokens.append(t.lemma_.lower())
    return " ".join(tokens)

# -----------------------------
# 2. Dummy dataset
# -----------------------------
texts = [
    "I feel hopeless and want to end everything",
    "I am very sad today, can you help me?",
    "What can I do to reduce anxiety?",
    "Thanks for your support",
    "I am planning to hurt myself",
]

labels = [1, 0, 0, 0, 1]   # 1 = crisis, 0 = non-crisis

processed = [preprocess(t) for t in texts]

# -----------------------------
# 3. Tokenization
# -----------------------------
tokenizer = Tokenizer(oov_token="<OOV>")
tokenizer.fit_on_texts(processed)
seqs = tokenizer.texts_to_sequences(processed)
X = pad_sequences(seqs, maxlen=10, padding='post')
y = np.array(labels)

# -----------------------------
# 4. GRU Model
# -----------------------------
model = Sequential()
model.add(Embedding(input_dim=len(tokenizer.word_index)+1, output_dim=32))
model.add(GRU(32))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer=Adam(0.01), loss='binary_crossentropy', metrics=['accuracy'])

# -----------------------------
# 5. Train model
# -----------------------------
model.fit(X, y, epochs=30, verbose=0)

# -----------------------------
# 6. Test Prediction
# -----------------------------
test_text = "I want to hurt myself tonight"
pp = preprocess(test_text)
seq = tokenizer.texts_to_sequences([pp])
padded = pad_sequences(seq, maxlen=10)

pred = model.predict(padded)[0][0]

print("User Input:", test_text)
print("Preprocessed:", pp)
print("Crisis Probability:", pred)

# -----------------------------
# Expected Output (Example)
# -----------------------------
# User Input: I want to hurt myself tonight
# Preprocessed: i want to hurt myself tonight
# Crisis Probability: 0.92
